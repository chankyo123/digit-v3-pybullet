# %%
# !pip install gym

import gym
import collections
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

#Hyperparameters
learning_rate = 0.0005
gamma         = 0.98
buffer_limit  = 50000
batch_size    = 32

class ReplayBuffer():
    def __init__(self):
        self.buffer = collections.deque(maxlen=buffer_limit)
    
    def put(self, transition):
        self.buffer.append(transition)
    
    def sample(self, n):
        mini_batch = random.sample(self.buffer, n)
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []
        
        for transition in mini_batch:
            s, a, r, s_prime, done_mask = transition
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            done_mask_lst.append([done_mask])

        return torch.tensor(s_lst, dtype=torch.float), torch.tensor(a_lst), \
               torch.tensor(r_lst), torch.tensor(s_prime_lst, dtype=torch.float), \
               torch.tensor(done_mask_lst)
    
    def size(self):
        return len(self.buffer)

class Qnet(nn.Module):
    def __init__(self):
        super(Qnet, self).__init__()
        self.fc1 = nn.Linear(4, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, 2)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x
      
    def sample_action(self, obs, epsilon):
        out = self.forward(obs)
        coin = random.random()
        if coin < epsilon:
            return random.randint(0,1)
        else : 
            return out.argmax().item()
            
def train(q, q_target, memory, optimizer):
    for i in range(10):
        s,a,r,s_prime,done_mask = memory.sample(batch_size)

        q_out = q(s)
        q_a = q_out.gather(1,a)
        max_q_prime = q_target(s_prime).max(1)[0].unsqueeze(1)
        target = r + gamma * max_q_prime * done_mask
        loss = F.smooth_l1_loss(q_a, target)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

def main():
#     env = gym.make('CartPole-v1')
    env = gym.make("CartPole-v1", render_mode="rgb_array")
#     env = gym.make('CartPole-v1',render_mode='rgb_array').unwrapped
    q = Qnet()
    q_target = Qnet()
    q_target.load_state_dict(q.state_dict())
    memory = ReplayBuffer()

    print_interval = 20
    score = 0.0  
    optimizer = optim.Adam(q.parameters(), lr=learning_rate)

    for n_epi in range(10000):
        epsilon = max(0.01, 0.08 - 0.01*(n_epi/200)) #Linear annealing from 8% to 1%
        s = env.reset()[0]
        done = False
        while not done:
            a = q.sample_action(torch.from_numpy(s).float(), epsilon)  
            s_prime, r, done, info, _ = env.step(a)
            done_mask = 0.0 if done else 1.0
            memory.put((s,a,r/100.0,s_prime, done_mask))
            s = s_prime
            score += r
            if score > 400:
                env.render()
            if done:
                break
            env.render()
        if memory.size()>2000:
            train(q, q_target, memory, optimizer)

        if n_epi%print_interval==0 and n_epi!=0:
            q_target.load_state_dict(q.state_dict())
            print("n_episode :{}, score : {:.1f}, n_buffer : {}, eps : {:.1f}%".format(
                                                            n_epi, score/print_interval, memory.size(), epsilon*100))
            score = 0.0
    env.render()
    env.close()

if __name__ == '__main__':
    main()
# Out:
# Requirement already satisfied: gym in /opt/homebrew/Caskroom/miniforge/base/envs/torch/lib/python3.8/site-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in /opt/homebrew/Caskroom/miniforge/base/envs/torch/lib/python3.8/site-packages (from gym) (1.24.2)
# Requirement already satisfied: gym-notices>=0.0.4 in /opt/homebrew/Caskroom/miniforge/base/envs/torch/lib/python3.8/site-packages (from gym) (0.0.8)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /opt/homebrew/Caskroom/miniforge/base/envs/torch/lib/python3.8/site-packages (from gym) (6.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/torch/lib/python3.8/site-packages (from gym) (2.2.1)
# Requirement already satisfied: zipp>=0.5 in /opt/homebrew/Caskroom/miniforge/base/envs/torch/lib/python3.8/site-packages (from importlib-metadata>=4.8.0->gym) (3.14.0)
# n_episode :20, score : 10.2, n_buffer : 204, eps : 7.9%
# n_episode :40, score : 10.0, n_buffer : 404, eps : 7.8%
# n_episode :60, score : 9.9, n_buffer : 603, eps : 7.7%
# n_episode :80, score : 9.8, n_buffer : 798, eps : 7.6%
# n_episode :100, score : 9.9, n_buffer : 997, eps : 7.5%
# n_episode :120, score : 9.4, n_buffer : 1185, eps : 7.4%
# n_episode :140, score : 9.6, n_buffer : 1376, eps : 7.3%
# n_episode :160, score : 9.7, n_buffer : 1569, eps : 7.2%
# n_episode :180, score : 9.6, n_buffer : 1761, eps : 7.1%
# n_episode :200, score : 9.8, n_buffer : 1958, eps : 7.0%
# n_episode :220, score : 36.4, n_buffer : 2686, eps : 6.9%
# n_episode :240, score : 18.4, n_buffer : 3054, eps : 6.8%
# n_episode :260, score : 10.2, n_buffer : 3258, eps : 6.7%
# n_episode :280, score : 11.3, n_buffer : 3485, eps : 6.6%
# n_episode :300, score : 12.7, n_buffer : 3738, eps : 6.5%
# n_episode :320, score : 33.8, n_buffer : 4414, eps : 6.4%
# n_episode :340, score : 126.6, n_buffer : 6946, eps : 6.3%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 120
#     117     env.close()
#     119 if __name__ == '__main__':
# --> 120     main()
#
# Cell In[32], line 107, in main()
#     105     if done:
#     106         break
# --> 107     env.render()
#     108 if memory.size()>2000:
#     109     train(q, q_target, memory, optimizer)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch/lib/python3.8/site-packages/gym/core.py:329, in Wrapper.render(self, *args, **kwargs)
#     325 def render(
#     326     self, *args, **kwargs
#     327 ) -> Optional[Union[RenderFrame, List[RenderFrame]]]:
#     328     """Renders the environment."""
# --> 329     return self.env.render(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py:51, in OrderEnforcing.render(self, *args, **kwargs)
#      46 if not self._disable_render_order_enforcing and not self._has_reset:
#      47     raise ResetNeeded(
#      48         "Cannot call `env.render()` before calling `env.reset()`, if this is a intended action, "
#      49         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      50     )
# ---> 51 return self.env.render(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch/lib/python3.8/site-packages/gym/wrappers/env_checker.py:55, in PassiveEnvChecker.render(self, *args, **kwargs)
#      53     return env_render_passive_checker(self.env, *args, **kwargs)
#      54 else:
# ---> 55     return self.env.render(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/torch/lib/python3.8/site-packages/gym/envs/classic_control/cartpole.py:303, in CartPoleEnv.render(self)
#     299     pygame.display.flip()
#     301 elif self.render_mode == "rgb_array":
#     302     return np.transpose(
# --> 303         np.array(pygame.surfarray.pixels3d(self.screen)), axes=(1, 0, 2)
#     304     )
#
# KeyboardInterrupt:

# %%
import gym
env = gym.make('CartPole-v1')
env.reset()

for i in range(1000):
    env.step(env.action_space.sample())
    env.render()

# %%
env.render()
